# %%
import pandas as pd

# %%
df1 = pd.read_excel('Фин данные ДАЙС.xlsx')
df1
# Out:
#        gara_id           bin  parent_id               fin_id       date_id  \
# 0      1124311  1.708400e+11        2.0  2001-01-01 00:00:00        year-1
# 1      1124311  1.708400e+11        2.0  2001-01-01 00:00:00        year-2
# 2      1124311  1.708400e+11        2.0  2001-01-01 00:00:00  year_current
# 3      1124311  1.708400e+11        3.0  2001-01-01 00:00:00        year-1
# 4      1124311  1.708400e+11        3.0  2001-01-01 00:00:00        year-2
# ...        ...           ...        ...                  ...           ...
# 46547  1397186  1.502400e+11       24.0              1.4.1.4  year_current
# 46548  1397186  1.502400e+11       24.0              1.4.1.4        year-1
# 46549  1397186  1.502400e+11       24.0              1.4.1.4        year-1
# 46550  1397186  1.502400e+11       24.0              1.4.1.4        year-2
# 46551  1397186  1.502400e+11       24.0              1.4.1.4        year-2
#
# ...

# %%
df2 = pd.read_excel('Данные о проектах.xlsx')
df2
# Out:
#      gara_id                application_name     author_id    builder_id  \
# 0    1027137     Заявка на гарантирование -              0  0.000000e+00
# 1    1242930  Заявка на гарантирование - 487   70440008408  1.104400e+11
# 2    1149569  Заявка на гарантирование - 483   60440000659  9.705400e+11
# 3     729352  Заявка на гарантирование - 335     540001174  9.603400e+11
# 4     790750  Заявка на гарантирование - 334   40440008640  9.603400e+11
# ..       ...                             ...           ...           ...
# 310      ,0"                               0             0  0.000000e+00
# 311        2                             NaN   31140001495  1.111400e+11
# 312      131                             NaN   70740004674  9.010400e+11
# 313  1318319  Заявка на гарантирование - 493  170440036256  1.312400e+11
# 314  1470655  Заявка на гарантирование - 505  110440013622  7.034001e+10
#
#     contractor_id  designer_id     engine_id    manager_id       status  \
# ...

# %%
merged_df = pd.merge(df1, df2, left_on='bin', right_on='builder_id', how='left')

# %%
merged_df
# Out:
#        gara_id_x           bin  parent_id               fin_id       date_id  \
# 0        1124311  1.708400e+11        2.0  2001-01-01 00:00:00        year-1
# 1        1124311  1.708400e+11        2.0  2001-01-01 00:00:00        year-2
# 2        1124311  1.708400e+11        2.0  2001-01-01 00:00:00  year_current
# 3        1124311  1.708400e+11        3.0  2001-01-01 00:00:00        year-1
# 4        1124311  1.708400e+11        3.0  2001-01-01 00:00:00        year-2
# ...          ...           ...        ...                  ...           ...
# 270671   1397186  1.502400e+11       24.0              1.4.1.4  year_current
# 270672   1397186  1.502400e+11       24.0              1.4.1.4        year-1
# 270673   1397186  1.502400e+11       24.0              1.4.1.4        year-1
# 270674   1397186  1.502400e+11       24.0              1.4.1.4        year-2
# 270675   1397186  1.502400e+11       24.0              1.4.1.4        year-2
#
# ...

# %%
merged_df.to_csv("Все данные об проекте.csv", index=False)
print("Data saved as CSV.")
# Out:
# Data saved as CSV.
