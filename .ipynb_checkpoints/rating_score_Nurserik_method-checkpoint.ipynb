# %%
import optbinning
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, precision_recall_curve, auc
from sklearn.feature_selection import f_classif
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from scipy.stats import chi2_contingency
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, classification_report
from tqdm import tqdm



from datetime import datetime

# %%
df = pd.read_excel('fin_data_of_proj.xlsx')

# %%
df
# Out:
#      gara_id                application_name     author_id    builder_id  \
# 0     729352  Заявка на гарантирование - 335  5.400012e+08  960340000376
# 1     790750  Заявка на гарантирование - 334  4.044001e+10  960340000376
# 2     845821  Заявка на гарантирование - 407  8.034001e+10   60340004172
# 3     781580  Заявка на гарантирование - 379  5.114001e+10  981040003722
# 4     746713  Заявка на гарантирование - 373  9.207400e+11   80440009616
# ..       ...                             ...           ...           ...
# 217       91                             NaN  1.054000e+10  110540015593
# 218       84                             NaN           NaN   50440002386
# 219      111                             NaN  6.074000e+10   60740002715
# 220        2                             NaN  3.114000e+10  111140016064
# 221      131                             NaN  7.074000e+10  901040000029
#
#      contractor_id   designer_id     engine_id    manager_id       status  \
# 0     9.603400e+11  0.000000e+00  2.210400e+11  1.904400e+11          NaN
# 1     9.603400e+11  0.000000e+00  2.210400e+11  1.904400e+11          NaN
# 2     6.034000e+10  0.000000e+00  1.304400e+11  2.109400e+11          NaN
# 3     9.810400e+11  0.000000e+00  7.054001e+10  2.109400e+11          NaN
# 4     8.044001e+10  0.000000e+00  2.208400e+11  2.202400e+11          NaN
# ..             ...           ...           ...           ...          ...
# 217   9.706400e+11           NaN  1.304400e+11  1.703400e+11  Завершенный
# 218   5.044000e+10           NaN  3.114000e+10  1.706400e+11  Завершенный
# 219   6.074000e+10           NaN  5.054001e+10  2.102400e+11  Завершенный
# 220   2.064000e+10           NaN  1.402400e+11  2.106400e+11  Завершенный
# 221   9.010400e+11  7.074000e+10  6.064000e+10  1.808400e+11  Действующий
#
#     decision_date        region_name  city_id         type  turn  \
# 0             NaT          г. Астана    18178  Стандартный  5, 7
# 1             NaT          г. Астана    18178  Стандартный   NaN
# 2             NaT         г. Шымкент    18277  Стандартный   NaN
# 3             NaT   Актюбинская обл.    18267  Стандартный   NaN
# 4             NaT         г. Алматы     18194  Стандартный     4
# ..            ...                ...      ...          ...   ...
# 217    2020-02-14          г. Астана    18178  Стандартный     6
# 218    2021-06-28    Атырауская обл.    18264  Стандартный   NaN
# 219    2021-04-27  Алматинская обл.     24184  Стандартный  7, 8
# 220    2022-02-24  Акмолинская обл.    177396  Стандартный    10
# 221    2022-06-10          г. Астана    18178  Стандартный   NaN
#
#                                                network  period_month  \
# 0                  будут выполнены за счет застройщика          13.0
# 1                                              имеются          21.0
# 2                                                 иное           9.0
# 3                  будут выполнены за счет застройщика          14.0
# 4                                              имеются          10.0
# ..                                                 ...           ...
# 217                                                NaN          16.0
# 218  Наружные сети будут подведены Застройщиком за ...           7.0
# 219  Строительство ИКИ за счет средств собственных ...          19.0
# 220  Строительство ИКИ за счет собственных средств ...           6.0
# 221  Строительство инженерных сетей за счет средств...          15.0
#
#     start_date   end_date  class  flat_area  build_qty  build_floor  \
# 0   2022-11-03 2023-12-03      4    9633.70        NaN          9.0
# 1   2022-11-03 2024-08-03      4   19350.28        NaN         12.0
# 2   2023-06-12 2024-03-12      4   11723.00        NaN          9.0
# 3   2022-10-21 2023-12-21      3    6698.30        NaN          5.0
# 4   2023-04-06 2024-01-06      4    4352.50        NaN          5.0
# ..         ...        ...    ...        ...        ...          ...
# 217 2019-11-15 2021-02-10      4   12857.79        1.0         12.0
# 218 2021-02-07 2022-02-18      3    4925.30        1.0          9.0
# 219 2021-03-05 2021-11-10      4    8999.00        1.0          9.0
# 220 2021-11-15 2022-04-05      3    8639.40        4.0          5.0
# 221 2021-11-26 2023-02-26      4   72945.60        4.0          9.0
#
#      build_area  com_area  park_area  flat_qty  com_qty  park_qty  flat_onerm  \
# 0       9633.70   7631.20     313.30        96      2.0       NaN        16.0
# 1      19350.28  16324.11    1398.43       141     12.0       NaN        26.0
# 2      11723.00   6650.80    1070.64        80      2.0    1635.0         8.0
# 3       6698.30   4842.00        NaN        60      NaN       NaN        20.0
# 4       4352.50   2544.20     117.20        58      3.0       NaN        35.0
# ..          ...       ...        ...       ...      ...       ...         ...
# 217    19814.66   1731.75       0.00       278     13.0       0.0       132.0
# 218     6326.20      0.00       0.00        72      0.0       0.0        36.0
# 219    11439.20    363.00       0.00       234     10.0       0.0       180.0
# 220    12721.20      0.00       0.00       190      0.0       0.0        95.0
# 221   114093.40   8035.65   13826.30      1040     67.0     368.0       320.0
#
#      flat_tworm  flat_threerm  flat_fourrm    cost_plan  flat_msprice  \
# 0          34.0          32.0          NaN      2228233      360000.0
# 1          35.0          40.0          NaN   3413044920      330000.0
# 2          40.0          24.0          NaN   2705190883      430000.0
# 3          20.0          20.0          NaN   1226556104      267500.0
# 4          19.0           4.0          NaN   1084238076      455450.0
# ..          ...           ...          ...          ...           ...
# 217       114.0          32.0          0.0   4490419686      295000.0
# 218        36.0           0.0          0.0    945714743      250000.0
# 219        54.0           0.0          0.0   2271535493      305000.0
# 220        65.0          25.0          5.0   1748059800      250000.0
# 221       400.0         272.0         48.0  21841445585      376000.0
#
#      build_mscost  flat_mscost  com_msprice  park_price     self_cost  \
# 0           231.0     231295.0     400000.0         NaN  3.342349e+08
# 1        176382.0     176382.0     330000.0         NaN  5.119567e+08
# 2        230759.0     430000.0     450000.0   2000000.0  2.972323e+08
# 3        183114.0     242690.0          NaN         NaN  1.839834e+08
# 4        249106.0     285000.0     525000.0         NaN  1.084238e+08
# ..            ...          ...          ...         ...           ...
# 217           NaN     193717.0     350000.0         NaN  3.838444e+08
# 218           NaN     149492.0          NaN         NaN  9.457147e+07
# 219           NaN     198575.0     400000.0         NaN  2.271535e+08
# 220           NaN     137413.0          NaN         NaN  1.748060e+08
# 221           NaN     191435.0     464000.0   2000000.0  3.276217e+09
#
#        unfin_cost    share_cost     warr_cost  comm_cost  cost_official  \
# 0    3.316000e+07  1.893998e+09  2.195073e+07        NaN     2228232541
# 218   1.150793e+10                              3.089054e+08
# 219   2.017238e+07                              1.181448e+06
# 220   8.022304e+06                              1.096000e+04
# 221   9.006396e+07                              5.157142e+06
#
#      Операционная прибыль  Долгосрочные финансовые обязательства  \
# 0            1.062896e+08                           2.308623e+07
# 1            1.062896e+08                           2.308623e+07
# 2            2.057717e+06                           2.739895e+06
# 3            4.661400e+04                           0.000000e+00
# 4            7.990000e+02                           0.000000e+00
# ..                    ...                                    ...
# 217          6.984120e+05                           8.789500e+04
# 218          2.429406e+08                           1.280199e+08
# 219          1.386600e+05                                    NaN
# 220          1.014255e+07                           0.000000e+00
# 221          1.217778e+06                           0.000000e+00
#
#      Краткосрочные финансовые обязательства  Итоговая прибыль (убыток)  \
# 0                                7384225.12               1.217043e+08
# 1                                7384225.12               1.217043e+08
# 2                                1000000.00               1.941551e+06
# 3                                   8401.00               3.596800e+04
# 4                                      0.00               7.990000e+02
# ..                                      ...                        ...
# 217                                    0.00               5.645760e+05
# 218                                    0.00               2.429406e+08
# 219                              1000000.00               1.350000e+05
# 220                                    0.00               4.020240e+05
# 221                             11264966.00               1.209970e+06
#
#      Расходы на финансирование  Коэффициент текущей ликвидности  \
# 0                  18539551.20                         2.903249
# 1                  18539551.20                         2.903249
# 2                     98956.32                         1.090348
# 3                        35.00                         1.423023
# 4                         0.00                         4.771901
# ..                         ...                              ...
# 217                       0.00                         0.866668
# 218                       0.00                         1.283775
# 219                       0.00                         1.502116
# 220                 9756784.00                        21.307559
# 221                       0.00                         1.144061
#
#      Коэффициент быстрой ликвидности  Коэффициент абсолютной ликвидности  \
# 0                           0.130899                            0.023270
# 1                           0.130899                            0.023270
# 2                           0.646736                            0.005857
# 3                           0.086060                            0.012768
# 4                           3.969841                            3.490445
# ..                               ...                                 ...
# 217                         0.411315                            0.000015
# 218                         0.481567                            0.001624
# 219                         0.074747                            0.053350
# 220                         6.995171                            0.009312
# 221                         0.057031                            0.012382
#
#      Коэффициент оборачиваемости запасов  Коэффициент оборачиваемости активов  \
# 0                               2.771208                             0.107103
# 1                               2.771208                             0.107103
# 2                               4.868977                             1.106941
# 3                               0.835875                             0.803647
# 4                                    inf                             0.010850
# ..                                   ...                                  ...
# 217                             0.168937                             0.013786
# 218                             5.319030                             0.188182
# 219                             0.142993                             0.058005
# 220                                  inf                             0.501043
# 221                             3.422389                             0.147845
#
#      Коэффициент оборачиваемости кредиторской задолженности       ROA  \
# 0                                             1.392067       0.206501
# 1                                             1.392067       0.206501
# 2                                             7.161518       0.069282
# 3                                             1.192999       0.026954
# 4                                                  inf       0.000608
# ..                                                 ...            ...
# 217                                           0.125601       0.074763
# 218                                           5.894806       0.021111
# 219                                           0.624092       0.006692
# 220                                         428.682117       0.050113
# 221                                           2.284841       0.013435
#
#           ROE  Коэффициент чистой прибыли  Коэффициент финансового левериджа  \
# 0    0.240344                    1.928060                           1.163885
# 1    0.240344                    1.928060                           1.163885
# 2    0.482492                    0.062588                           6.964214
# 3    0.087549                    0.033539                           3.248147
# 4    0.000762                    0.056070                           1.252455
# ..        ...                         ...                                ...
# 217  0.888420                    5.423140                          11.883087
# 218  0.047214                    0.112182                           2.236496
# 219  0.034918                    0.115375                           5.217551
# 220  0.063015                    0.100018                           1.257460
# 221  0.705714                    0.090870                          52.529763
#
#      Коэффициент финансовой независимости  Коэффициент долговой нагрузки  \
# 0                                0.859191                            1.0
# 1                                0.859191                            1.0
# 2                                0.143591                            1.0
# 3                                0.307868                            1.0
# 4                                0.798432                            1.0
# ..                                    ...                            ...
# 217                              0.084153                            1.0
# 218                              0.447128                            1.0
# 219                              0.191661                            1.0
# 220                              0.795254                            1.0
# 221                              0.019037                            1.0
#
#      Коэффициент долг на капитал  Коэффициент покрытия процентов  \
# 0                       0.060174                        5.733126
# 1                       0.060174                        5.733126
# 2                       0.929396                       20.794199
# 3                       0.020449                     1331.828571
# 4                       0.000000                             inf
# ..                           ...                             ...
# 217                     0.138312                             inf
# 218                     0.024880                             inf
# 219                          NaN                             inf
# 220                     0.000000                        1.039538
# 221                     6.570286                             inf
#
#      Покрытие долга  Target  life_cycle      today  real_life_cycle  \
# 0          3.488284       0         395 2024-11-01              729
# 1          3.488284       0         639 2024-11-01              729
# 2          0.550207       0         274 2024-11-01              508
# 3          5.548625       0         426 2024-11-01              742
# 4               inf       0         275 2024-11-01              575
# ..              ...     ...         ...        ...              ...
# 217        7.945981       1         453 2024-11-01             1813
# 218        1.897679       0         376 2024-11-01             1363
# 219             NaN       0         250 2024-11-01             1337
# 220             inf       0         141 2024-11-01             1082
# 221        0.108103       1         457 2024-11-01             1071
#
#      percent_of_life_cycle  Target 2
# 0                 1.845570         0
# 1                 1.140845         0
# 2                 1.854015         0
# 3                 1.741784         0
# 4                 2.090909         0
# ..                     ...       ...
# 217               4.002208         0
# 218               3.625000         0
# 219               5.348000         0
# 220               7.673759         0
# 221               2.343545         0
#
# [222 rows x 96 columns]

# %%
# Unfin_cost and Season of every year

def get_season(date):
    month = date.month if pd.notnull(date) else None
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3, 4, 5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    elif month in [9, 10, 11]:
        return 'Fall'
    else:
        return None

df['season'] = df['dpg_date'].apply(get_season)
df['unfin_coff'] = df['unfin_cost']/df['cost_plan']

# %%
# Inflaction of every year 8%

annual_inflation_rate = 0.08
inflation_reference_date = datetime(2024, 11, 1)


df['dpg_date'] = pd.to_datetime(df['dpg_date'], errors='coerce')

financial_columns = [
    'cost_plan', 'flat_msprice', 'build_mscost', 'flat_mscost', 'com_msprice', 'park_price',
    'self_cost', 'unfin_cost', 'share_cost', 'warr_cost', 'comm_cost', 'cost_official',
    'Итого краткосрочные активы', 'Итого краткосрочных обязательств', 'Денежные средства',
    'Краткосрочная дебиторская задолженность', 'Запасы', 'Себестоимость', 'Доход от реализации',
    'Итого активы', 'Итого капитал', 'Итого пассивы', 'Краткосрочная кредиторская задолженность',
    'Операционная прибыль', 'Долгосрочные финансовые обязательства', 'Краткосрочные финансовые обязательства',
    'Итоговая прибыль (убыток)', 'Расходы на финансирование'
]

df['years_since_dpg'] = (inflation_reference_date - df['dpg_date']).dt.days / 365.25
df['inflation_factor'] = (1 + annual_inflation_rate) ** df['years_since_dpg']

for col in financial_columns:
    if col in df.columns:
        df[col] = df[col] * df['inflation_factor']

df.drop(columns=['years_since_dpg', 'inflation_factor'], inplace=True)

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

df.replace([np.inf, -np.inf], np.nan, inplace=True)

df = df[:-11]
df = df.drop(columns=['application_name', 'author_id', 'engine_id', 'manager_id', 'status', 'decision_date',
                          'region_name', 'build_mscost', 'dpg_num_text', 'prolongation', 'update_date', 'state_id',
                          'create_date', 'annul_date', 'state_name', 'дата фин данных', 'life_cycle', 'today',
                          'gara_id', 'contractor_id', 'designer_id', 'build_qty', 'real_life_cycle', 'bin', 
                          'date', 'start_date', 'end_date', 'turn', 'network', 'Коэффициент долговой нагрузки', 'dpg_add_num'])

df['coff_doxoda_ot_real'] = df['Доход от реализации'] / df['cost_plan']

df = df[df['type'] != 'Паркинг']

df = df.drop(columns=['type'])


df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.drop('Target 2', axis = 1)
df = df.dropna(axis=1, how='all')

non_numeric_cols = df.select_dtypes(include=['object', 'datetime', 'timedelta']).columns

# label_encoder = LabelEncoder()
# for col in non_numeric_cols:
#     df[col] = label_encoder.fit_transform(df[col].astype(str))

# %%
df
# Out:
#        builder_id city_id period_month class  flat_area build_floor  \
# 0    960340000376   18178         13.0     4    9633.70         9.0
# 1    960340000376   18178         21.0     4   19350.28        12.0
# 2     60340004172   18277          9.0     4   11723.00         9.0
# 3    981040003722   18267         14.0     3    6698.30         5.0
# 4     80440009616   18194         10.0     4    4352.50         5.0
# ..            ...     ...          ...   ...        ...         ...
# 206  131240018048   18178         12.0     4   66054.54        14.0
# 207   50640012251   18277         10.0     3    5712.00         5.0
# 208  170840003753   18194         23.0     4   31440.78         9.0
# 209   31040001233   18274         10.0     4   10974.61         5.0
# 210   31040001233   18274         10.0     4   13734.47         5.0
#
#      build_area  com_area  park_area  flat_qty com_qty  park_qty  flat_onerm  \
# 0       9633.70   7631.20     313.30        96     2.0       0.0        16.0
# 1      19350.28  16324.11    1398.43       141    12.0       0.0        26.0
# 2      11723.00   6650.80    1070.64        80     2.0    1635.0         8.0
# 3       6698.30   4842.00       0.00        60     0.0       0.0        20.0
# 4       4352.50   2544.20     117.20        58     3.0       0.0        35.0
# ..          ...       ...        ...       ...     ...       ...         ...
# 206    66054.54  42367.37    3742.01       674    29.0    5223.0       253.0
# 207     5712.00   4190.55       0.00        45     0.0       0.0         0.0
# 208    31440.78  19913.75    1970.11       261     0.0       0.0         3.0
# 209    10974.61   6795.68       0.00       120     0.0       0.0        45.0
# 210    13734.47   8561.63       0.00       155     0.0       0.0        60.0
#
#      flat_tworm  flat_threerm flat_fourrm     cost_plan   flat_msprice  \
# 0          34.0          32.0         0.0  2.475277e+06  399913.089452
# 1          35.0          40.0         0.0  3.750923e+09  362668.708918
# 2          40.0          24.0         0.0  2.951772e+09  469194.904792
# 208                2.580390e+06                      2.678794e+06
# 209                1.678574e+07                      1.037753e+07
# 210                1.676100e+07                      1.036224e+07
#
#      Денежные средства  Краткосрочная дебиторская задолженность        Запасы  \
# 0         1.508942e+06                             6.979116e+06  1.321679e+07
# 1         1.492813e+06                             6.904520e+06  1.307552e+07
# 2         1.325195e+05                             1.450104e+07  6.312514e+06
# 3         1.306465e+04                             7.499240e+04  1.332578e+06
# 4         1.019992e+06                             1.400910e+05  0.000000e+00
# ..                 ...                                      ...           ...
# 206       3.242786e+04                             5.285934e+05  1.040219e+07
# 207       1.888412e+07                             4.554227e+09  2.127447e+09
# 208       1.577888e+04                             6.367922e+03  7.965164e+05
# 209       2.398543e+06                             3.293948e+06  8.913456e+06
# 210       2.395008e+06                             3.289093e+06  8.900319e+06
#
#      Себестоимость  Доход от реализации  Итого активы  Итого капитал  \
# 0     3.662647e+07         7.012104e+07  6.547058e+08   5.625175e+08
# 1     3.623499e+07         6.937155e+07  6.477080e+08   5.565050e+08
# 2     3.073548e+07         3.384857e+07  3.057846e+07   4.390798e+06
# 3     1.113869e+06         1.188065e+06  1.478341e+06   4.551335e+05
# 4     4.205744e+03         1.573014e+04  1.449755e+06   1.157531e+06
# ..             ...                  ...           ...            ...
# 206   1.659226e+07         1.847623e+07  1.721686e+07   6.084550e+06
# 207   7.350482e+09         9.006159e+09  1.452873e+10   5.671917e+09
# 208   1.221420e+05         9.413981e+04  3.157383e+06   4.785890e+05
# 209   4.286303e+07         4.986700e+07  2.398462e+07   1.327099e+07
# 210   4.279986e+07         4.979350e+07  2.394927e+07   1.325143e+07
#
#      Итого пассивы  Краткосрочная кредиторская задолженность  \
# 0     6.547058e+08                              2.631086e+07
# 1     6.477079e+08                              2.602963e+07
# 2     3.057846e+07                              4.291756e+06
# 3     1.478341e+06                              9.336711e+05
# 4     1.449755e+06                              0.000000e+00
# ..             ...                                       ...
# 206   1.721686e+07                              3.615340e+06
# 207   1.452873e+10                              3.059571e+09
# 208   3.157383e+06                              1.874883e+03
# 209   2.398461e+07                              2.338436e+05
# 210   2.394926e+07                              2.334989e+05
#
#      Операционная прибыль  Долгосрочные финансовые обязательства  \
# 0            1.180739e+08                           2.564579e+07
# 1            1.168118e+08                           2.537168e+07
# 2            2.245280e+06                           2.989639e+06
# 3            5.164043e+04                           0.000000e+00
# 4            8.819919e+02                           0.000000e+00
# ..                    ...                                    ...
# 206          1.480661e+06                           0.000000e+00
# 207          1.549037e+09                           1.435252e+09
# 208         -1.047481e+05                           0.000000e+00
# 209          3.598756e+06                           0.000000e+00
# 210          3.593452e+06                           0.000000e+00
#
#      Краткосрочные финансовые обязательства  Итоговая прибыль (убыток)  \
# 0                              8.202912e+06               1.351976e+08
# 1                              8.115235e+06               1.337525e+08
# 2                              1.091151e+06               2.118525e+06
# 3                              9.306888e+03               3.984646e+04
# 4                              0.000000e+00               8.819919e+02
# ..                                      ...                        ...
# 206                            0.000000e+00               1.424518e+06
# 207                            4.466440e+08               1.249930e+09
# 208                            2.622315e+06              -1.047481e+05
# 209                            0.000000e+00               2.442556e+07
# 210                            0.000000e+00               2.438956e+07
#
#      Расходы на финансирование  Коэффициент текущей ликвидности  \
# 0                 2.059503e+07                         2.903249
# 1                 2.037489e+07                         2.903249
# 2                 1.079763e+05                         1.090348
# 3                 3.877408e+01                         1.423023
# 4                 0.000000e+00                         4.771901
# ..                         ...                              ...
# 206               5.614254e+04                         1.164960
# 207               0.000000e+00                         2.261633
# 208               0.000000e+00                         0.963266
# 209               0.000000e+00                         1.617508
# 210               0.000000e+00                         1.617508
#
#      Коэффициент быстрой ликвидности  Коэффициент абсолютной ликвидности  \
# 0                           0.130899                            0.023270
# 1                           0.130899                            0.023270
# 2                           0.646736                            0.005857
# 3                           0.086060                            0.012768
# 4                           3.969841                            3.490445
# ..                               ...                                 ...
# 206                         0.055373                            0.003201
# 207                         1.047944                            0.004327
# 208                         0.008267                            0.005890
# 209                         0.548540                            0.231128
# 210                         0.548540                            0.231128
#
#      Коэффициент оборачиваемости запасов  Коэффициент оборачиваемости активов  \
# 0                               2.771208                             0.107103
# 1                               2.771208                             0.107103
# 2                               4.868977                             1.106941
# 3                               0.835875                             0.803647
# 4                               0.000000                             0.010850
# ..                                   ...                                  ...
# 206                             1.595074                             1.073148
# 207                             3.455072                             0.619886
# 208                             0.153345                             0.029816
# 209                             4.808801                             2.079124
# 210                             4.808801                             2.079124
#
#      Коэффициент оборачиваемости кредиторской задолженности       ROA  \
# 0                                             1.392067       0.206501
# 1                                             1.392067       0.206501
# 2                                             7.161518       0.069282
# 3                                             1.192999       0.026954
# 4                                             0.000000       0.000608
# ..                                                 ...            ...
# 206                                           4.589407       0.082740
# 207                                           2.402455       0.086032
# 208                                          65.146437      -0.033176
# 209                                         183.297907       1.018384
# 210                                         183.297907       1.018384
#
#           ROE  Коэффициент чистой прибыли  Коэффициент финансового левериджа  \
# 0    0.240344                    1.928060                           1.163885
# 1    0.240344                    1.928060                           1.163885
# 2    0.482492                    0.062588                           6.964214
# 3    0.087549                    0.033539                           3.248147
# 4    0.000762                    0.056070                           1.252455
# ..        ...                         ...                                ...
# 206  0.234121                    0.077100                           2.829602
# 207  0.220372                    0.138786                           2.561520
# 208 -0.218869                   -1.112687                           6.597274
# 209  1.840523                    0.489814                           1.807297
# 210  1.840523                    0.489814                           1.807297
#
#      Коэффициент финансовой независимости  Коэффициент долг на капитал  \
# 0                                0.859191                     0.060174
# 1                                0.859191                     0.060174
# 2                                0.143591                     0.929396
# 3                                0.307868                     0.020449
# 4                                0.798432                     0.000000
# ..                                    ...                          ...
# 206                              0.353407                     0.000000
# 207                              0.390393                     0.331792
# 208                              0.151578                     5.479264
# 209                              0.553313                     0.000000
# 210                              0.553313                     0.000000
#
#      Коэффициент покрытия процентов  Покрытие долга  Target  \
# 0                          5.733126        3.488284       0
# 1                          5.733126        3.488284       0
# 2                         20.794199        0.550207       0
# 3                       1331.828571        5.548625       0
# 4                          0.000000        0.000000       0
# ..                              ...             ...     ...
# 206                       26.373242        0.000000       0
# 207                        0.000000        0.823126       0
# 208                        0.000000       -0.039945       0
# 209                        0.000000        0.000000       0
# 210                        0.000000        0.000000       0
#
#      percent_of_life_cycle  season  unfin_coff  coff_doxoda_ot_real
# 0                 1.845570  Summer   14.881747            28.328569
# 1                 1.140845  Summer    0.143970             0.018495
# 2                 1.854015    Fall    0.109875             0.011467
# 3                 1.741784  Summer    0.150448             0.000874
# 4                 2.090909  Summer    0.210085             0.000013
# ..                     ...     ...         ...                  ...
# 206               0.673973  Spring    0.145033             0.001282
# 207               0.921311  Spring    0.104933             5.333327
# 208               0.462197  Spring    0.000000             0.000013
# 209               0.601974  Spring    0.000000             0.020510
# 210               0.519737  Spring    0.000000             0.016920
#
# [210 rows x 66 columns]

# %%
df.to_excel('df.xlsx')

# %%
pd.set_option('display.max_columns', None)
if df[col].dtype == 'object':
    df[col] = df[col].str.replace(',', '')
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# %%
df.replace(np.NaN, 0, inplace=True)

# %%
cat_cols = df.columns[(df.nunique() < 40) & (df.columns != 'Target')]
df[cat_cols] = df[cat_cols].astype(str)

# %%
X = df.drop(['Target'], axis = 1)
y = df['Target']

# %%
iv_score_dict = {}
for col in tqdm(X.columns):
    if col in cat_cols:
        optb = optbinning.OptimalBinning(dtype='categorical')
        optb.fit(df[col], df['Target'])
    else:
        optb = optbinning.OptimalBinning(dtype='numerical')
        optb.fit(df[col], df['Target'])
    binning_table = optb.binning_table
    binning_table.build()
    iv_score_dict[col] = binning_table.iv
iv_score_df = pd.Series(iv_score_dict)
iv_score_df.sort_values(ascending=False, inplace=True)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 65/65 [00:03<00:00, 16.92it/s]

# %%
pd.set_option('display.max_columns', None)

# %%
iv_score_df
# Out:
# Коэффициент оборачиваемости активов       1.283359
# period_month                              1.175856
# city_id                                   0.954683
# share_cost                                0.937570
# com_qty                                   0.856165
#                                             ...
# Краткосрочные финансовые обязательства    0.126889
# Коэффициент долг на капитал               0.082434
# park_price                                0.074951
# class                                     0.020817
# flat_fourrm                               0.000000
# Length: 65, dtype: float64

# %%
iv_score_df2 = pd.DataFrame(iv_score_df, columns=['Numbers']).reset_index()
iv_score_df3 = iv_score_df2[iv_score_df2['Numbers'].between(0.2, 2)]
selected_features = iv_score_df3['index']
selected_features
# Out:
# 0          Коэффициент оборачиваемости активов
# 1                                 period_month
# 2                                      city_id
# 3                                   share_cost
# 4                                      com_qty
# 5                                     dpg_date
# 6                   Итого краткосрочные активы
# 7                        percent_of_life_cycle
# 8                                 Итого активы
# 9                                Итого пассивы
# 10                   Расходы на финансирование
# 11    Краткосрочная кредиторская задолженность
# 12                                         ROE
# 13                                 build_floor
# 14                        Операционная прибыль
# 15                                         ROA
# 16                   Итоговая прибыль (убыток)
# 17                                    park_qty
# 18                                  unfin_coff
# 19                                 com_msprice
# 20                                     dpg_num
# 21       Долгосрочные финансовые обязательства
# 22                               Себестоимость
# 23                                flat_threerm
# 24                         coff_doxoda_ot_real
# 25                           Денежные средства
# 26                                      Запасы
# 27        Коэффициент финансовой независимости
# 28                                   warr_cost
# 29          Коэффициент абсолютной ликвидности
# 30                                 flat_mscost
# 31              Коэффициент покрытия процентов
# 32                                  builder_id
# 33                         Доход от реализации
# 34                                    com_area
# 35     Краткосрочная дебиторская задолженность
# 36                                  unfin_cost
# 37         Коэффициент оборачиваемости запасов
# 38                                  flat_inner
# 39                               Итого капитал
# 40                                 flat_height
# 41                                  flat_onerm
# 42             Коэффициент текущей ликвидности
# 43                               cost_official
# 44             Коэффициент быстрой ликвидности
# 45                                   park_area
# 46                                flat_msprice
# 47                                   cost_plan
# 48                  Коэффициент чистой прибыли
# 49            Итого краткосрочных обязательств
# Name: index, dtype: object

# %%
from sklearn import linear_model

binning_process = optbinning.BinningProcess(
  variable_names=X.columns.to_list())
# estimator
estimator = LogisticRegression()
scorecard = optbinning.Scorecard(
  binning_process=binning_process,
  estimator=estimator,
  scaling_method="min_max",
  scaling_method_params={"min": 300, "max": 850},

)

# %%
scorecard.fit(X, y)
# Out:
# Scorecard(binning_process=BinningProcess(variable_names=['builder_id',
#                                                          'city_id',
#                                                          'period_month',
#                                                          'class', 'flat_area',
#                                                          'build_floor',
#                                                          'build_area',
#                                                          'com_area',
#                                                          'park_area',
#                                                          'flat_qty', 'com_qty',
#                                                          'park_qty',
#                                                          'flat_onerm',
#                                                          'flat_tworm',
#                                                          'flat_threerm',
#                                                          'flat_fourrm',
#                                                          'cost_plan',
#                                                          'flat_msprice',
#                                                          'flat_mscost',
#                                                          'com_msprice',
#                                                          'park_price',
#                                                          'self_cost',
#                                                          'unfin_cost',
#                                                          'share_cost',
#                                                          'warr_cost',
#                                                          'comm_cost',
#                                                          'cost_official',
#                                                          'flat_inner',
#                                                          'flat_height',
#                                                          'dpg_date', ...]),
#           estimator=LogisticRegression(), scaling_method='min_max',
#           scaling_method_params={'max': 850, 'min': 300})

# %%
scorecard.intercept_
# Out:
# 0

# %%
scorecard_df = scorecard.table(style="detailed")

# %%
len(scorecard_df['Variable'].unique())
# Out:
# 65

# %%
scorecard_df.to_excel('scorecard.xlsx')

# %%
prediction = scorecard.predict_proba(X_test)[:, 1]
print(f"Prediction shape after re-generation: {prediction.shape}")

# %%
print(f"X_test shape: {X_test.shape}")
print(f"y_test shape: {y_test.shape}")

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

threshold = 0.5
y_pred = (prediction >= threshold).astype(int)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

auc = roc_auc_score(y_test, prediction)
print(f"AUC: {auc:.2f}")

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

ConfusionMatrixDisplay(conf_matrix, display_labels=["Class 0", "Class 1"]).plot()

# %% [markdown]
# # Scorecard of other models

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from xgboost import XGBClassifier

imputer = SimpleImputer(strategy="mean")
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

models = {
    "RandomForest": RandomForestClassifier(),
    "GradientBoosting": GradientBoostingClassifier(),
    "AdaBoost": AdaBoostClassifier(),
    "Bagging": BaggingClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric="logloss"),
}

fitted_models = {}
for name, model in models.items():
    model.fit(X_train, y_train)
    fitted_models[name] = model

# %%
import pandas as pd

X_train = pd.DataFrame(X_train, columns=binning_process.variable_names)
X_test = pd.DataFrame(X_test, columns=binning_process.variable_names)

print(X_train.head())
print(X_test.head())
